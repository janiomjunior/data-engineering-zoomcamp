# %%
import pyspark

# %%
pyspark.__file__
# Out:
# '/home/janiomjr/projects/docker-zoomcamp/data-engineering-zoomcamp/06-batch/code/.venv/lib/python3.13/site-packages/pyspark/__init__.py'

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder \
    .master("local[*]") \
    .appName('test') \
    .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/02/26 08:42:14 WARN Utils: Your hostname, MFdell, resolves to a loopback address: 127.0.1.1; using 10.255.255.254 instead (on interface lo)
# 26/02/26 08:42:14 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/02/26 08:42:14 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
# !wget https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-11.parquet
# Out:
# --2026-02-26 08:43:02--  https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2025-11.parquet
# Resolving d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)... 3.165.4.195, 3.165.4.197, 3.165.4.125, ...
# Connecting to d37ci6vzurychx.cloudfront.net (d37ci6vzurychx.cloudfront.net)|3.165.4.195|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 71134255 (68M) [binary/octet-stream]
# Saving to: ‘yellow_tripdata_2025-11.parquet’
#
# yellow_tripdata_202 100%[===================>]  67.84M  66.8MB/s    in 1.0s
#
# 2026-02-26 08:43:03 (66.8 MB/s) - ‘yellow_tripdata_2025-11.parquet’ saved [71134255/71134255]

# %%
# !head taxi_zone_lookup.csv
# Out:
# "LocationID","Borough","Zone","service_zone"
# 1,"EWR","Newark Airport","EWR"
# 2,"Queens","Jamaica Bay","Boro Zone"
# 3,"Bronx","Allerton/Pelham Gardens","Boro Zone"
# 4,"Manhattan","Alphabet City","Yellow Zone"
# 5,"Staten Island","Arden Heights","Boro Zone"
# 6,"Staten Island","Arrochar/Fort Wadsworth","Boro Zone"
# 7,"Queens","Astoria","Boro Zone"
# 8,"Queens","Astoria Park","Boro Zone"
# 9,"Queens","Auburndale","Boro Zone"

# %%
df = spark.read \
    .option("header", "true") \
    .csv('taxi_zone_lookup.csv')

# %%
df.show()
# Out:
# +----------+-------------+--------------------+------------+
# |LocationID|      Borough|                Zone|service_zone|
# +----------+-------------+--------------------+------------+
# |         1|          EWR|      Newark Airport|         EWR|
# |         2|       Queens|         Jamaica Bay|   Boro Zone|
# |         3|        Bronx|Allerton/Pelham G...|   Boro Zone|
# |         4|    Manhattan|       Alphabet City| Yellow Zone|
# |         5|Staten Island|       Arden Heights|   Boro Zone|
# |         6|Staten Island|Arrochar/Fort Wad...|   Boro Zone|
# |         7|       Queens|             Astoria|   Boro Zone|
# |         8|       Queens|        Astoria Park|   Boro Zone|
# |         9|       Queens|          Auburndale|   Boro Zone|
# |        10|       Queens|        Baisley Park|   Boro Zone|
# |        11|     Brooklyn|          Bath Beach|   Boro Zone|
# |        12|    Manhattan|        Battery Park| Yellow Zone|
# |        13|    Manhattan|   Battery Park City| Yellow Zone|
# |        14|     Brooklyn|           Bay Ridge|   Boro Zone|
# |        15|       Queens|Bay Terrace/Fort ...|   Boro Zone|
# |        16|       Queens|             Bayside|   Boro Zone|
# |        17|     Brooklyn|             Bedford|   Boro Zone|
# |        18|        Bronx|        Bedford Park|   Boro Zone|
# |        19|       Queens|           Bellerose|   Boro Zone|
# |        20|        Bronx|             Belmont|   Boro Zone|
# +----------+-------------+--------------------+------------+
# only showing top 20 rows

# %%
df.write.parquet('zones')

# %%
# !ls -lh
# Out:
# total 295M
# -rw-r--r-- 1 janiomjr janiomjr 7.5K Feb 24 09:29 03_test.ipynb
# -rw-r--r-- 1 janiomjr janiomjr  19K Feb 24 08:58 04_pyspark.ipynb
# -rw-r--r-- 1 janiomjr janiomjr  33K Feb 24 08:58 05_taxi_schema.ipynb
# -rw-r--r-- 1 janiomjr janiomjr 8.7K Feb 24 08:58 06_spark_sql.ipynb
# -rw-r--r-- 1 janiomjr janiomjr 2.5K Feb 24 08:58 06_spark_sql.py
# -rw-r--r-- 1 janiomjr janiomjr 2.6K Feb 24 08:58 06_spark_sql_big_query.py
# -rw-r--r-- 1 janiomjr janiomjr 7.6K Feb 24 08:58 07_groupby_join.ipynb
# -rw-r--r-- 1 janiomjr janiomjr  12K Feb 24 08:58 08_rdds.ipynb
# -rw-r--r-- 1 janiomjr janiomjr 4.3K Feb 24 08:58 09_spark_gcs.ipynb
# -rw-r--r-- 1 janiomjr janiomjr    0 Feb 24 09:05 README.md
# -rw-r--r-- 1 janiomjr janiomjr  337 Feb 24 09:10 Untitled.ipynb
# -rw-r--r-- 1 janiomjr janiomjr 3.8K Feb 24 08:58 cloud.md
# -rwxr-xr-x 1 janiomjr janiomjr  544 Feb 24 08:58 download_data.sh
# -rw-r--r-- 1 janiomjr janiomjr 295M Jun 29  2022 fhvhv_tripdata_2021-01.parquet
# -rw-r--r-- 1 janiomjr janiomjr  17K Feb 24 08:58 homework.ipynb
# -rw-r--r-- 1 janiomjr janiomjr   82 Feb 24 09:05 main.py
# -rw-r--r-- 1 janiomjr janiomjr  220 Feb 24 09:15 pyproject.toml
# -rw-r--r-- 1 janiomjr janiomjr  13K Feb 22  2024 taxi_zone_lookup.csv
# -rw-r--r-- 1 janiomjr janiomjr 163K Feb 24 09:15 uv.lock
# drwxr-xr-x 2 janiomjr janiomjr 4.0K Feb 24 09:30 zones
